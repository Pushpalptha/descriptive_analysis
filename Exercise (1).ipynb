# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/user/Downloads/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Relevent columns names are Age and Sex
df_subset = df[['Age', 'Sex']]
df_subset
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
df_subset = df[['Age', 'Sex']].dropna(subset=['Age'])
df_subset
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 885  39.0  female
# 886  27.0    male
# 887  19.0  female
# 889  26.0    male
# 890  32.0    male
#
# [714 rows x 2 columns]

# %%
# Relevent variables names are male_ages and female_ages
male_ages = df[df['Sex'] == 'male']['Age']
female_ages = df[df['Sex'] == 'female']['Age']

plt.hist([male_ages, female_ages], bins=30, label=['Male', 'Female'], stacked=True, alpha=0.7)

plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# By using Seaborn library
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Age", hue="Sex", bins=30, multiple="stack", kde=False, alpha=0.7)

plt.title("Age Distribution by Gender")
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
